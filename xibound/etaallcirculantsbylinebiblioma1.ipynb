# %%
import csv
from csv import reader

candidatos=[]

# %%
#PARES 48 -100 Degree up to 12

for vertices in range(90,91,2):
    print("VERT=",vertices)
    for degree in range(12,13):     
        # All degrees (up to complement) are present up to 60 vertices, 
        # then degrees at most 20 up to 65 vertices, 
        # at most 16 up to 70 vertices 
        # and at most 12 up to 100 vertices.
        
        #data=list(csv.reader(open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r'),delimiter=' '))
        
        with open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r') as read_obj:
            csv_reader = reader(read_obj,delimiter=' ')
            header = next(csv_reader)
            # Check file as empty
            if header != None:
            # Iterate over each row after the header in the csv
                for row in csv_reader:
                # row variable is a list that represents a row in csv
                    lin=[]
                    for s in row:
                        n=eval(s)
                        lin=lin+[n]
                    g = graphs.CirculantGraph(vertices,lin)
                    if 3*len(g.independent_set())*g.clique_number() <= vertices:
                        print('EUREKA')
                        print([vertices,degree,lin,len(g.independent_set()),g.clique_number(),2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number()))])
                        candidatos=candidatos + [[vertices,degree,lin]] 
                        
        print(degree)

    print(vertices)  

print(candidatos)

for vertices in range(92,95,2):
    print("VERT=",vertices)
    for degree in range(2,13):     
        # All degrees (up to complement) are present up to 60 vertices, 
        # then degrees at most 20 up to 65 vertices, 
        # at most 16 up to 70 vertices 
        # and at most 12 up to 100 vertices.
        
        #data=list(csv.reader(open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r'),delimiter=' '))
        
        with open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r') as read_obj:
            csv_reader = reader(read_obj,delimiter=' ')
            header = next(csv_reader)
            # Check file as empty
            if header != None:
            # Iterate over each row after the header in the csv
                for row in csv_reader:
                # row variable is a list that represents a row in csv
                    lin=[]
                    for s in row:
                        n=eval(s)
                        lin=lin+[n]
                    g = graphs.CirculantGraph(vertices,lin)
                    if 3*len(g.independent_set())*g.clique_number() <= vertices:
                        print('EUREKA')
                        print([vertices,degree,lin,len(g.independent_set()),g.clique_number(),2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number()))])
                        candidatos=candidatos + [[vertices,degree,lin]] 
                        
        print(degree)

    print(vertices)  

print(candidatos)


for vertices in range(96,97,2):
    print("VERT=",vertices)
    for degree in range(9,13):     
        # All degrees (up to complement) are present up to 60 vertices, 
        # then degrees at most 20 up to 65 vertices, 
        # at most 16 up to 70 vertices 
        # and at most 12 up to 100 vertices.
        
        #data=list(csv.reader(open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r'),delimiter=' '))
        
        with open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r') as read_obj:
            csv_reader = reader(read_obj,delimiter=' ')
            header = next(csv_reader)
            # Check file as empty
            if header != None:
            # Iterate over each row after the header in the csv
                for row in csv_reader:
                # row variable is a list that represents a row in csv
                    lin=[]
                    for s in row:
                        n=eval(s)
                        lin=lin+[n]
                    g = graphs.CirculantGraph(vertices,lin)
                    if 3*len(g.independent_set())*g.clique_number() <= vertices:
                        print('EUREKA')
                        print([vertices,degree,lin,len(g.independent_set()),g.clique_number(),2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number()))])
                        candidatos=candidatos + [[vertices,degree,lin]] 
                        
        print(degree)

    print(vertices)  

print(candidatos)

for vertices in range(98,101,2):
    print("VERT=",vertices)
    for degree in range(2,13):     
        # All degrees (up to complement) are present up to 60 vertices, 
        # then degrees at most 20 up to 65 vertices, 
        # at most 16 up to 70 vertices 
        # and at most 12 up to 100 vertices.
        
        #data=list(csv.reader(open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r'),delimiter=' '))
        
        with open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r') as read_obj:
            csv_reader = reader(read_obj,delimiter=' ')
            header = next(csv_reader)
            # Check file as empty
            if header != None:
            # Iterate over each row after the header in the csv

                for row in csv_reader:
                # row variable is a list that represents a row in csv
                    lin=[]
                    for s in row:
                        n=eval(s)
                        lin=lin+[n]
                    g = graphs.CirculantGraph(vertices,lin)
                    if 3*len(g.independent_set())*g.clique_number() <= vertices:
                        print('EUREKA')
                        print([vertices,degree,lin,len(g.independent_set()),g.clique_number(),2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number()))])
                        candidatos=candidatos + [[vertices,degree,lin]] 
                        
        print(degree)

    print(vertices)  

print(candidatos)
# Out:
# VERT= 90

# %%
# IMPARES 49 -100 Degree up to 12

for vertices in range(49,100,2):
    print("VERT=",vertices)
    for degree in range(2,13,2):  
        # All degrees (up to complement) are present up to 60 vertices, 
        # then degrees at most 20 up to 65 vertices, 
        # at most 16 up to 70 vertices 
        # and at most 12 up to 100 vertices.
        
        #data=list(csv.reader(open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r'),delimiter=' '))
        
        with open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r') as read_obj:
            csv_reader = reader(read_obj,delimiter=' ')
            header = next(csv_reader)
            # Check file as empty
            if header != None:
            # Iterate over each row after the header in the csv
                for row in csv_reader:
                # row variable is a list that represents a row in csv
                    lin=[]
                    for s in row:
                        n=eval(s)
                        lin=lin+[n]
                    g = graphs.CirculantGraph(vertices,lin)
                    if 3*len(g.independent_set())*g.clique_number() <= vertices:
                        print('EUREKA')
                        print([vertices,degree,lin,len(g.independent_set()),g.clique_number(),2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number()))])
                        candidatos=candidatos + [[vertices,degree,lin]] 
                        
        print(degree)

    print(vertices)  

print(candidatos)

# %%
#PARES 48 -70 Degree 13-16

for vertices in range(48,65,2):
    print("VERT=",vertices)
    for degree in range(13,17):     
        # All degrees (up to complement) are present up to 60 vertices, 
        # then degrees at most 20 up to 65 vertices, 
        # at most 16 up to 70 vertices 
        # and at most 12 up to 100 vertices.
        
        #data=list(csv.reader(open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r'),delimiter=' '))
        
        with open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r') as read_obj:
            csv_reader = reader(read_obj,delimiter=' ')
            header = next(csv_reader)
            # Check file as empty
            if header != None:
            # Iterate over each row after the header in the csv
                for row in csv_reader:
                # row variable is a list that represents a row in csv
                    lin=[]
                    for s in row:
                        n=eval(s)
                        lin=lin+[n]
                    g = graphs.CirculantGraph(vertices,lin)
                    if 3*len(g.independent_set())*g.clique_number() <= vertices:
                        print('EUREKA')
                        print([vertices,degree,lin,len(g.independent_set()),g.clique_number(),2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number()))])
                        candidatos=candidatos + [[vertices,degree,lin]] 
                        
        print(degree)

    print(vertices)  

print(candidatos)

# %%
# IMPARES 49 - 70 Degree 13-16


for vertices in range(49,50,2):
    print("VERT=",vertices)
    for degree in range(16,17,2):  
        # All degrees (up to complement) are present up to 60 vertices, 
        # then degrees at most 20 up to 65 vertices, 
        # at most 16 up to 70 vertices 
        # and at most 12 up to 100 vertices.
        
        #data=list(csv.reader(open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r'),delimiter=' '))
        
        with open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r') as read_obj:
            csv_reader = reader(read_obj,delimiter=' ')
            header = next(csv_reader)
            # Check file as empty
            if header != None:
            # Iterate over each row after the header in the csv
                for row in csv_reader:
                # row variable is a list that represents a row in csv
                    lin=[]
                    for s in row:
                        n=eval(s)
                        lin=lin+[n]
                    g = graphs.CirculantGraph(vertices,lin)
                    if 3*len(g.independent_set())*g.clique_number() <= vertices:
                        print('EUREKA')
                        print([vertices,degree,lin,len(g.independent_set()),g.clique_number(),2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number()))])
                        candidatos=candidatos + [[vertices,degree,lin]] 
                        
        print(degree)

    print(vertices)  

print(candidatos)

# %%
#PARES 48 -65 Degree 17-20

for vertices in range(48,65,2):
    print("VERT=",vertices)
    for degree in range(17,21):     
        # All degrees (up to complement) are present up to 60 vertices, 
        # then degrees at most 20 up to 65 vertices, 
        # at most 16 up to 70 vertices 
        # and at most 12 up to 100 vertices.
        
        #data=list(csv.reader(open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r'),delimiter=' '))
        
        with open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r') as read_obj:
            csv_reader = reader(read_obj,delimiter=' ')
            header = next(csv_reader)
            # Check file as empty
            if header != None:
            # Iterate over each row after the header in the csv
                for row in csv_reader:
                # row variable is a list that represents a row in csv
                    lin=[]
                    for s in row:
                        n=eval(s)
                        lin=lin+[n]
                    g = graphs.CirculantGraph(vertices,lin)
                    if 3*len(g.independent_set())*g.clique_number() <= vertices:
                        print('EUREKA')
                        print([vertices,degree,lin,len(g.independent_set()),g.clique_number(),2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number()))])
                        candidatos=candidatos + [[vertices,degree,lin]] 
                        
        print(degree)

    print(vertices)  

print(candidatos)

# %%
# IMPARES 49 -65 Degree up to 17-20

candidatos=[]

for vertices in range(49,66,2):
    print("VERT=",vertices)
    for degree in range(18,21,2):   
        # All degrees (up to complement) are present up to 60 vertices, 
        # then degrees at most 20 up to 65 vertices, 
        # at most 16 up to 70 vertices 
        # and at most 12 up to 100 vertices.
        
        #data=list(csv.reader(open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r'),delimiter=' '))
        
        with open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r') as read_obj:
            csv_reader = reader(read_obj,delimiter=' ')
            header = next(csv_reader)
            # Check file as empty
            if header != None:
            # Iterate over each row after the header in the csv
                for row in csv_reader:
                # row variable is a list that represents a row in csv
                lin=[]
                    for s in row:
                        n=eval(s)
                        lin=lin+[n]
                    g = graphs.CirculantGraph(vertices,lin)
                    if 3*len(g.independent_set())*g.clique_number() <= vertices:
                        print('EUREKA')
                        print([vertices,degree,lin,len(g.independent_set()),g.clique_number(),2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number()))])
                        candidatos=candidatos + [[vertices,degree,lin]] 
                        
        print(degree)

    print(vertices)  

print(candidatos)

# %%
# IMPARES 49 -65 Degree 21  up to complement

candidatos=[]

for vertices in range(49,60,2):
    print("VERT=",vertices)
    for degree in range(22,int((vertices + 1)/2),2):   
        # All degrees (up to complement) are present up to 60 vertices, 
        # then degrees at most 20 up to 65 vertices, 
        # at most 16 up to 70 vertices 
        # and at most 12 up to 100 vertices.
        
        #data=list(csv.reader(open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r'),delimiter=' '))
        
        with open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r') as read_obj:
            csv_reader = reader(read_obj,delimiter=' ')
            header = next(csv_reader)
            # Check file as empty
            if header != None:
            # Iterate over each row after the header in the csv
                for row in csv_reader:
                # row variable is a list that represents a row in csv
                    lin=[]
                    for s in row:
                        n=eval(s)
                        lin=lin+[n]
                    g = graphs.CirculantGraph(vertices,lin)
                    if 3*len(g.independent_set())*g.clique_number() <= vertices:
                        print('EUREKA')
                        print([vertices,degree,lin,len(g.independent_set()),g.clique_number(),2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number()))])
                        candidatos=candidatos + [[vertices,degree,lin]] 
                        
        print(degree)

    print(vertices)  

print(candidatos)

# %%
#PARES 48 -65 Degree 21 up to complement

for vertices in range(48,61,2):
    print("VERT=",vertices)
    for degree in range(21,int(vertices/2)):     
        # All degrees (up to complement) are present up to 60 vertices, 
        # then degrees at most 20 up to 65 vertices, 
        # at most 16 up to 70 vertices 
        # and at most 12 up to 100 vertices.
        
        #data=list(csv.reader(open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r'),delimiter=' '))
        
        with open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r') as read_obj:
            csv_reader = reader(read_obj,delimiter=' ')
            header = next(csv_reader)
            # Check file as empty
            if header != None:
            # Iterate over each row after the header in the csv
                for row in csv_reader:
                # row variable is a list that represents a row in csv
                    lin=[]
                    for s in row:
                        n=eval(s)
                        lin=lin+[n]
                    g = graphs.CirculantGraph(vertices,lin)
                    if 3*len(g.independent_set())*g.clique_number() <= vertices:
                        print('EUREKA')
                        print([vertices,degree,lin,len(g.independent_set()),g.clique_number(),2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number()))])
                        candidatos=candidatos + [[vertices,degree,lin]] 
                        
        print(degree)

    print(vertices)  

print(candidatos)
