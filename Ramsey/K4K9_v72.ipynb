# %% [markdown]
# K4K9_72.g6 es block-circulant, una cota inferior de R(4,9) con 72 vértices, pero no tiene dimensión = omega (ni su complementario)

# %%
l=['~?@Gsa[o?@?O@_E?K?R_Ho@k?Q[@Ho@kZo?@w??X_?ZK?BNo??_SDX_WEXoD@[k?oNL_@IfU?Ae]k?Egyk?Io|VAp_GGor_A@DI[?ODseK@?Mk?[gO[k@bG_kX?MSD@}OKX?g]HKWD?bodM?S@NADb?gH`yE[?gP`xG@rCSo{Q@bPIKN@_BeKC]Fe?pggHw]BQCiGKrKBKBICKrK@XAXA@eXwT_YP?Xe]DQCkOBKroSoKq?KrN?eOec@eX`wd_Ya@eX`wFb@ad?E?H@sgWU_AO@grE?tIOOCGbDgBJO__HDEFGEhW?OCdESgEUc?_GY_rcKSi_?KAgLYBAtO?C`T]E@_i_?ECdTxOS@T??c`ijKDKDS?Qo@TJKEgAi?LG?itwgI@TAO@Gii]WE?i_W?`DTZKHSAik_??iskoj?TTK??DSl']

# %%
grs=graphs_list.from_graph6(l)

# %%
g=grs[0].complement()

# %%
f8=graphs.CompleteGraph(9)

# %%
f8.delete_edges([[1,2],[3,4],[5,6],[7,8]])

# %%
h=g.subgraph_search(f8);h
# Out:
# Subgraph of (): Graph on 9 vertices

# %%
g.independent_set()
# Out:
# [18, 46, 66]

# %%
g.clique_number()
# Out:
# 8

# %%
vv=len(g.vertices())

# %%
alpha=len(g.independent_set());
omega=g.clique_number();
eta_aprox=2*alpha/(alpha+(vv/omega));eta_aprox
# Out:
# 0.5

# %%
g.is_vertex_transitive()
# Out:
# False

# %%
h=g.complement()
hs=g.subgraph_search(graphs.CycleGraph(4));hs
# Out:
# Subgraph of (): Graph on 4 vertices

# %%
print('alpha =',len(h.independent_set()),'omega =',h.clique_number())
# Out:
# alpha = 8 omega = 3

# %%
alpha=len(h.independent_set());
omega=h.clique_number();
eta_aprox=2*alpha/(alpha+(vv/omega));eta_aprox
# Out:
# 0.5
