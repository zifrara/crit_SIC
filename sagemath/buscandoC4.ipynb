# %%
def get_graphs_from_file(filename):
    f = open( filename, 'r')
    graph_list=[ Graph( l[:-1] ) for l in f ]
    f.close()
    return graph_list

# %%
L = get_graphs_from_file("omegaless4.g6")

# %%
L
# Out:
# [Graph on 11 vertices,
#  Graph on 12 vertices,
#  Graph on 13 vertices,
#  Graph on 14 vertices,
#  Graph on 14 vertices,
#  Graph on 15 vertices,
#  Graph on 15 vertices,
#  Graph on 15 vertices,
#  Graph on 15 vertices,
#  Graph on 16 vertices,
#  Graph on 16 vertices,
#  Graph on 16 vertices,
#  Graph on 18 vertices,
#  Graph on 18 vertices,
#  Graph on 18 vertices,
#  Graph on 18 vertices,
#  Graph on 19 vertices,
#  Graph on 20 vertices,
#  Graph on 20 vertices,
#  Graph on 20 vertices,
#  Graph on 20 vertices,
#  Graph on 20 vertices,
#  Graph on 20 vertices,
#  Graph on 20 vertices,
#  Graph on 20 vertices,
#  Graph on 20 vertices,
#  Graph on 20 vertices,
#  Graph on 21 vertices,
#  Graph on 21 vertices,
#  Graph on 23 vertices,
#  Graph on 26 vertices,
#  Graph on 32 vertices,
#  Graph on 32 vertices,
#  Graph on 32 vertices,
#  Graph on 32 vertices,
#  Graph on 32 vertices,
#  Graph on 32 vertices,
#  Graph on 35 vertices,
#  Graph on 35 vertices,
#  Graph on 43 vertices,
# ...

# %%
C4=graphs.CycleGraph(4)
len(C4.vertices())
# Out:
# 4

# %%
Lres=[]
i=0
for g in L:
    if len(g.subgraph_search(C4).vertices()) > 0:
        i=i+1
    else:
        Lres.append(g)
print(len(L)," ",i)
# Out:
# 144   144

# %%
Lres
# Out:
# []

# %%
L[0].show()
# Out:
# Graphics object consisting of 34 graphics primitives

# %%
L[0].subgraph_search(C4)
# Out:
# Subgraph of (): Graph on 4 vertices

# %%
L[0].subgraph_search(C4)
# Out:
# Subgraph of (): Graph on 4 vertices

# %%
C5.subgraph_search(C4)
