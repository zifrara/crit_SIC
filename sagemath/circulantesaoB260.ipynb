# %%
import csv

candidatos=[]

# %%
#IMPARES
# 75-99
# Hecho para 75
# Hecho para 77 grados 2 a 10
# Hecho para 77-99 grados 2 a 6

candidatos=[]

for vertices in range(79,100,2):
    print("VERT=",vertices)
    for degree in range(2, 7,2):     # All degrees (up to complement) are present up to 60 vertices, 
        # then degrees at most 20 up to 65 vertices, 
        # at most 16 up to 70 vertices 
        # and at most 12 up to 100 vertices.
        data=list(csv.reader(open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r'),delimiter=' '))
    
        datos=[];
        for row in data:
            lin=[]
            for s in row:
                n=eval(s)
                lin=lin+[n]
            g = graphs.CirculantGraph(vertices,lin)
            if 2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number())) <= 0.6:
                print([vertices,degree,lin,len(g.independent_set()),g.clique_number(),2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number()))])
                if 3*len(g.independent_set())*g.clique_number() <= vertices:
                    print(EUREKA)
                    candidatos=candidatos + [[vertices,degree,lin]] 
     
        print(degree)

    print(vertices)  

print(candidatos)
# Out:
# VERT= 79
# 2
# 4
# 6
# 79
# VERT= 81
# 2
# 4
# 6
# 81
# VERT= 83
# 2
# 4
# 6
# 83
# VERT= 85
# 2
# 4
# 6
# 85
# VERT= 87
# 2
# 4
# 6
# 87
# VERT= 89
# 2
# 4
# 6
# 89
# VERT= 91
# 2
# 4
# 6
# 91
# VERT= 93
# 2
# 4
# 6
# 93
# VERT= 95
# 2
# 4
# 6
# 95
# VERT= 97
# 2
# 4
# 6
# 97
# VERT= 99
# 2
# 4
# 6
# 99
# []

# %%
#candidatos=[]

for vertices in range(81,100,2):
    print("VERT=",vertices)
    for degree in range(8, 13,2):     # All degrees (up to complement) are present up to 60 vertices, 
        # then degrees at most 20 up to 65 vertices, 
        # at most 16 up to 70 vertices 
        # and at most 12 up to 100 vertices.
        data=list(csv.reader(open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r'),delimiter=' '))
    
        datos=[];
        for row in data:
            lin=[]
            for s in row:
                n=eval(s)
                lin=lin+[n]
            g = graphs.CirculantGraph(vertices,lin)
            if 2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number())) <= 0.6:
                print([vertices,degree,lin,len(g.independent_set()),g.clique_number(),2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number()))])
                if 3*len(g.independent_set())*g.clique_number() <= vertices:
                    print(EUREKA)
                    candidatos=candidatos + [[vertices,degree,lin]] 
     
        print(degree)

    print(vertices)  

print(candidatos)
# Out:
# VERT= 81
# 8
# 10
# 12
# 81
# VERT= 83
# 8
# 10
# 12
# 83
# VERT= 85
# 8
# 10
