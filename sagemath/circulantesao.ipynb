# %%
import csv

candidatos=[]

# %%
#PARES

candidatos=[]

for vertices in range(88,101,2):
    print("VERT=",vertices)
    for degree in range(2,11):     # All degrees (up to complement) are present up to 60 vertices, 
        # then degrees at most 20 up to 65 vertices, 
        # at most 16 up to 70 vertices 
        # and at most 12 up to 100 vertices.
        data=list(csv.reader(open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r'),delimiter=' '))
    
        datos=[];
        for row in data:
            lin=[]
            for s in row:
                n=eval(s)
                lin=lin+[n]
            g = graphs.CirculantGraph(vertices,lin)
            if 2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number())) <= 0.53:
                print([vertices,degree,lin,len(g.independent_set()),g.clique_number(),2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number()))])
                if 3*len(g.independent_set())*g.clique_number() <= vertices:
                    print(EUREKA)
                    candidatos=candidatos + [[vertices,degree,lin]]
     
        print(degree)

    print(vertices) 

print(candidatos)

for vertices in range(86,87,2):
    print("VERT=",vertices)
    for degree in range(10,11):     # All degrees (up to complement) are present up to 60 vertices, 
        # then degrees at most 20 up to 65 vertices, 
        # at most 16 up to 70 vertices 
        # and at most 12 up to 100 vertices.
        data=list(csv.reader(open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r'),delimiter=' '))
    
        datos=[];
        for row in data:
            lin=[]
            for s in row:
                n=eval(s)
                lin=lin+[n]
            g = graphs.CirculantGraph(vertices,lin)
            if 2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number())) <= 0.53:
                print([vertices,degree,lin,len(g.independent_set()),g.clique_number(),2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number()))])
                if 3*len(g.independent_set())*g.clique_number() <= vertices:
                    print(EUREKA)
                    candidatos=candidatos + [[vertices,degree,lin]]
     
        print(degree)

    print(vertices) 

print(candidatos)
    
for vertices in range(84,101,2):
    print("VERT=",vertices)
    for degree in range(11,14):     # All degrees (up to complement) are present up to 60 vertices, 
        # then degrees at most 20 up to 65 vertices, 
        # at most 16 up to 70 vertices 
        # and at most 12 up to 100 vertices.
        data=list(csv.reader(open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r'),delimiter=' '))
    
        datos=[];
        for row in data:
            lin=[]
            for s in row:
                n=eval(s)
                lin=lin+[n]
            g = graphs.CirculantGraph(vertices,lin)
            if 2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number())) <= 0.53:
                print([vertices,degree,lin,len(g.independent_set()),g.clique_number(),2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number()))])
                if 3*len(g.independent_set())*g.clique_number() <= vertices:
                    print(EUREKA)
                    candidatos=candidatos + [[vertices,degree,lin]]
     
        print(degree)

    print(vertices) 

print(candidatos)

# %%
#IMPARES
# 49,51,53,55,57,59,61-63-65,67,69, 71, 73
# 65 flata el de 20

candidatos=[]

for vertices in range(61,66,2):
    print("VERT=",vertices)
    for degree in range(20, 21,2):     # All degrees (up to complement) are present up to 60 vertices, 
        # then degrees at most 20 up to 65 vertices, 
        # at most 16 up to 70 vertices 
        # and at most 12 up to 100 vertices.
        data=list(csv.reader(open(str(vertices)+'/circ'+str(vertices)+'.'+str(degree)+'.txt','r'),delimiter=' '))
    
        datos=[];
        for row in data:
            lin=[]
            for s in row:
                n=eval(s)
                lin=lin+[n]
            g = graphs.CirculantGraph(vertices,lin)
            if 2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number())) <= 0.6:
                print([vertices,degree,lin,len(g.independent_set()),g.clique_number(),2*len(g.independent_set())/(len(g.independent_set())+(vertices/g.clique_number()))])
                if 3*len(g.independent_set())*g.clique_number() <= vertices:
                    print(EUREKA)
                    candidatos=candidatos + [[vertices,degree,lin]] 
     
        print(degree)

    print(vertices)  

print(candidatos)

# %%
print(candidatos)
